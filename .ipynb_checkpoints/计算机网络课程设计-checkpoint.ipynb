# %%
from tkinter import *
import tkinter.messagebox
from PIL import Image, ImageTk
from tkinter import ttk
import pandas as pd

root = Tk()
root.geometry("700x500")
root.resizable(width=False, height=False)
#root = Toplevel()
root.title('网桥转发表模拟工具')
#fm=Frame(root)
#fm.grid(row = 10, column = 0,columnspan=14, rowspan=7)
lan1 = ["H1","H2"]
lan2 = ["H3","H4","H5"]
lan3 = ["H6","H7"]
hostSegOne = {"H1":1,"H2":2,"H3":3,"H4":3, "H5":3, "H6":3, "H7":3}
hostSegTwo = {"H1":1,"H2":1,"H3":2,"H4":3,"H5":4, "H6":5, "H7":5}
hostSegThree = {"H1":1,"H2":1,"H3":1,"H4":1,"H5":1,"H6":2,"H7":3}
S1 = {}
S2 = {}
S3 = {}
dataIO = []
i = 2
# 下拉菜单的选择事件
# def chooseSrc(*args):
#     print(cbSrcAddr.get())

def tableSave(dataIO):
    colName = ['发送的帧','S1地址','S1接口','S2地址','S2接口','S3地址','S3接口','S1的处理','S2的处理','S3的处理']
    csvFile = pd.DataFrame(columns = colName, data = dataIO)
    csvFile.to_csv('testcsv.csv',encoding='gbk',index_label = "序号")
    
def btnClick():
    global i
    if(i == 9):
        return
    dataChip = ["","","","","","","","","",""]
    srcAddr = varSrc.get()
    desAddr = varDes.get()
    handleB1 = ""
    handleB2 = ""
    handleB3 = ""
    seqS = [0,0,0]
    loc = 0
    if(srcAddr in lan1):
        seqS = [1,2,3]
    elif(srcAddr in lan2):
        seqS = [2,1,3]
    elif(srcAddr in lan3):
        seqS = [3,2,1]
    else:
        return
    count = 0
    while(count!=3):
        if(seqS[count] == 1):
            if(srcAddr in S1):
                handleB1 = "转发,不登记"
            else:
                S1[srcAddr] = hostSegOne[srcAddr]
                handleB1 = "转发,登记"
                Label(root, text=S1[srcAddr]).grid(row=8 + i,column=3)
                Label(root, text=srcAddr).grid(row=8 + i,column=2)
                dataChip[2 * count + 1] = srcAddr
                dataChip[2 * count + 2] = S1[srcAddr]
            if(desAddr in S1):
                if(desAddr in lan1):
                    for c in range(count + 1, 3):
                        seqS[c] = 0
                    
        elif(seqS[count] == 2):
            if(srcAddr in S2):
                handleB2 = "转发,不登记"
            else:
                S2[srcAddr] = hostSegTwo[srcAddr]
                handleB2 = "转发,登记"
                Label(root, text=S2[srcAddr]).grid(row=8 + i,column=5)
                Label(root, text=srcAddr).grid(row=8 + i,column=4)
                dataChip[2 * count + 1] = srcAddr
                dataChip[2 * count + 2] = S2[srcAddr]
            if(desAddr in S2):
                q = 2
                if(desAddr in lan1):
                    q = 3
                elif(desAddr in lan3):
                    q = 1
                for c in range(count, 3):
                    if(seqS[c] == q):
                        seqS[c] = 0
                    if(q == 2):
                        seqS[c] = 0
            #if(desAddr in S2):
        elif(seqS[count] == 3):
            if(srcAddr in S3):
                handleB3 = "转发,不登记"
            else:
                S3[srcAddr] = hostSegThree[srcAddr]
                handleB3 = "转发,登记"
                Label(root, text=S3[srcAddr]).grid(row=8 + i,column=7)
                Label(root, text=srcAddr).grid(row=8 + i,column=6)
                dataChip[2 * count + 1] = srcAddr
                dataChip[2 * count + 2] = S3[srcAddr]
            if(desAddr in S3):
                if(desAddr in lan3):
                    for c in range(count + 1, 3):
                        seqS[c] = 0
        count = count + 1
    Label(root, text=srcAddr + "->" + desAddr).grid(row=8 + i, column=0, columnspan=2)
    dataChip[0] = srcAddr + "->" + desAddr
    Label(root, text=handleB1).grid(row=8 + i,column=8)
    Label(root, text=handleB2).grid(row=8 + i,column=9)
    Label(root, text=handleB3).grid(row=8 + i,column=10)
    dataChip[7] = handleB1
    dataChip[8] = handleB2
    dataChip[9] = handleB3
    dataIO.append(dataChip)
    i = i + 1
    if(i == 9):
        #root.pack_forget()
        #fm.destroy()
        i = i - 1
        boolSave=tkinter.messagebox.askokcancel('提示', '要是否进行保存?')
        if(boolSave):
            tableSave(dataIO)
        

if __name__ == "__main__":
    varSrc = StringVar()
    varDes = StringVar()
    img = Image.open('VLN1.png')  # 打开图片
    photo = ImageTk.PhotoImage(img)  # 用PIL模块的PhotoImage打开
    imglabel = Label(root, image=photo)
    imglabel.grid(row=0, column=0, columnspan=14, rowspan=7)

    #Label(root, text="Answer:").grid(row=3, column=0, sticky=S + N)
    Label(root, text= "出发地址:").grid(row=7, column = 0)
    
    cbSrcAddr=ttk.Combobox(root,textvariable=varSrc) #初始化 
    cbSrcAddr["values"]=("H1","H2","H3","H4","H5","H6","H7")
    cbSrcAddr.current(0)  #选择第一个  
    cbSrcAddr.bind("<<ComboboxSelected>>",chooseSrc)  #绑定事件,(下拉列表框被选中时，绑定go()函数)  
    cbSrcAddr.grid(row=7, column=1, columnspan=4)
    
    #answerEntry = Entry(root,textvariable=varSrc)
    #answerEntry.grid(row=7, column=1, columnspan=4)
    Label(root, text= "目的地址:").grid(row=7, column = 7)
    
    cbSrcAddr=ttk.Combobox(root,textvariable=varDes) #初始化 
    cbSrcAddr["values"]=("H1","H2","H3","H4","H5","H6","H7")
    cbSrcAddr.current(0)  #选择第一个  
    cbSrcAddr.bind("<<ComboboxSelected>>",chooseSrc)  #绑定事件,(下拉列表框被选中时，绑定go()函数)  
    cbSrcAddr.grid(row=7, column=7, columnspan=4)
    #加一个按钮
    #theButton = Button(root, text="确定", command=callback)  # 按下按钮 执行 callback函数
    btn = Button(root,text="点击测试",command=btnClick).grid(row=7, column=12, sticky='S')#
    #btn.pack(side = BOTTOM)
    #theButton.pack()
    # programming head
    Label(root, text="发送的帧").grid(row=8, column=0, rowspan=2, columnspan=2)
    Label(root, text="S1的转发表").grid(row=8,column=2,columnspan=2)
    Label(root, text="地址").grid(row=9,column=2)
    Label(root, text="接口").grid(row=9,column=3)
    Label(root, text="S2的转发表").grid(row=8,column=4,columnspan=2)
    Label(root, text="地址").grid(row=9,column=4)
    Label(root, text="接口").grid(row=9,column=5)
    Label(root, text="S3的转发表").grid(row=8,column=6,columnspan=2)
    Label(root, text="地址").grid(row=9,column=6)
    Label(root, text="接口").grid(row=9,column=7)
    Label(root, text="S1的处理").grid(row=8,column=8,rowspan=2)
    Label(root, text="S2的处理").grid(row=8,column=9,rowspan=2)
    Label(root, text="S3的处理").grid(row= 8,column=10,rowspan=2)
    mainloop()

# %%
    import tkinter  
    from  tkinter  import ttk  
      
    def go(*args):   #处理事件，*args表示可变参数  
        print(comboxlist.get()) #打印选中的值  
      
    win=tkinter.Tk() #构造窗体  
    comvalue=tkinter.StringVar()#窗体自带的文本，新建一个值  
    comboxlist=ttk.Combobox(win,textvariable=comvalue) #初始化  
    comboxlist["values"]=("1","2","3","4")  
    comboxlist.current(0)  #选择第一个  
    comboxlist.bind("<<ComboboxSelected>>",go)  #绑定事件,(下拉列表框被选中时，绑定go()函数)  
    comboxlist.pack()  
      
    win.mainloop() #进入消息循环
